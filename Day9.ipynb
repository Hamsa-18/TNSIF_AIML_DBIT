# %% [markdown]
# <a href="https://colab.research.google.com/github/Hamsa-18/Capgemini-training/blob/main/Day9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv(r'/content/gold_price_data.csv')

# %%
print(df.shape)
# Out:
# (5215, 7)

# %%
print(df.columns)
# Out:
# Index(['date', 'open', 'high', 'low', 'close', 'adj_close', 'volume'], dtype='object')

# %%
print(df.head())
# Out:
#          date       open       high        low      close  adj_close    volume
# 0  2004-11-18  44.380001  44.380001  44.490002  44.070000  44.430000   5992000
# 1  2004-11-19  44.779999  44.779999  44.919998  44.470001  44.490002  11655300
# 2  2004-11-22  44.950001  44.950001  44.970001  44.740002  44.750000  11996000
# 3  2004-11-23  44.750000  44.750000  44.919998  44.720001  44.880001   3169200
# 4  2004-11-24  45.049999  45.049999  45.049999  44.790001  44.930000   6105100

# %%
print(df.isnull().sum())
df = df.drop_duplicates()
# Out:
# date         0
# open         0
# high         0
# low          0
# close        0
# adj_close    0
# volume       0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
for feature in ['open', 'high', 'low', 'close', 'volume']:
    plt.hist(df[feature])
    plt.title(feature)
    plt.show()

# %%
import pandas as pd
df = pd.read_csv(r'/content/gold_price_data.csv')
features = ['open', 'high', 'low', 'close', 'adj_close']
import matplotlib.pyplot as plt
import seaborn as sns
for col in features:
    plt.figure(figsize=(6, 4))
    sns.boxplot(x=df[col], color="pink")
    plt.title(f"Boxplot of {col}")
    plt.xlabel(col)
    plt.show()

# %%
corr_matrix = df[features].corr()
print(corr_matrix)
plt.figure(figsize=(6, 4))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()
# Out:
#                open      high       low     close  adj_close
# open       1.000000  1.000000  0.999911  0.999920   0.999823
# high       1.000000  1.000000  0.999911  0.999920   0.999823
# low        0.999911  0.999911  1.000000  0.999864   0.999919
# close      0.999920  0.999920  0.999864  1.000000   0.999894
# adj_close  0.999823  0.999823  0.999919  0.999894   1.000000

# %%
X = df[['open', 'high', 'low', 'volume']]
y = df['close']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)
print('MSE:', mse)
print('RMSE:', rmse)
print('R2:', r2)
# Out:
# MSE: 0.24576732890531058
# RMSE: 0.495749260115747
# R2: 0.9999070953341468

# %%
plt.scatter(y_test, y_pred)
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Actual vs Predicted')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')
plt.show()

# %%
coefficients = pd.Series(model.coef_, index=X.columns)
print(coefficients)
# Out:
# open      2.698801e-01
# high      2.698801e-01
# low       4.553823e-01
# volume   -5.771114e-08
# dtype: float64
