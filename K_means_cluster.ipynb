# %% [markdown]
# <a href="https://colab.research.google.com/github/Hamsa-18/Capgemini-training/blob/main/K_means_cluster.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
data=pd.read_csv("/content/student_kmeans_dataset.csv")

# %%
X = df[["Study_Hours", "Exam_Score"]]

# %%
for k in [4]:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    df[f"Cluster_K{k}"] = kmeans.fit_predict(X)

# %%
plt.figure(figsize=(6,4))
plt.scatter(df["Study_Hours"], df["Exam_Score"],
                c=df[f"Cluster_K{k}"], cmap="viridis", s=80)
plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1],
                c="red", marker="X", s=200, label="Centroids")
plt.xlabel("Study Hours")
plt.ylabel("Exam Score")
plt.title(f"K-Means Clustering (K={k})")
plt.legend()
plt.show()

# Show dataset with cluster assignments
print(df)
# Out:
#     Study_Hours  Exam_Score  Cluster  Cluster_K2  Cluster_K4  Cluster_K3
# 0             1          35        2           1           2           2
# 1             2          40        2           1           2           2
# 2             2          42        2           1           2           2
# 3             3          50        2           1           0           2
# 4             3          48        2           1           0           2
# 5             4          55        0           1           0           0
# 6             5          60        0           1           0           0
# 7             6          65        0           0           3           0
# 8             6          70        0           0           3           0
# 9             7          75        1           0           3           1
# 10            8          80        1           0           1           1
# 11            8          82        1           0           1           1
# ...

# %%
for k in [3]:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    df[f"Cluster_K{k}"] = kmeans.fit_predict(X)

# %%
plt.figure(figsize=(6,4))
plt.scatter(df["Study_Hours"], df["Exam_Score"],
                c=df[f"Cluster_K{k}"], cmap="viridis", s=80)
plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1],
                c="red", marker="X", s=200, label="Centroids")
plt.xlabel("Study Hours")
plt.ylabel("Exam Score")
plt.title(f"K-Means Clustering (K={k})")
plt.legend()
plt.show()

# Show dataset with cluster assignments
print(df)
# Out:
#     Study_Hours  Exam_Score  Cluster  Cluster_K2  Cluster_K4  Cluster_K3
# 0             1          35        2           1           2           2
# 1             2          40        2           1           2           2
# 2             2          42        2           1           2           2
# 3             3          50        2           1           0           2
# 4             3          48        2           1           0           2
# 5             4          55        0           1           0           0
# 6             5          60        0           1           0           0
# 7             6          65        0           0           3           0
# 8             6          70        0           0           3           0
# 9             7          75        1           0           3           1
# 10            8          80        1           0           1           1
# 11            8          82        1           0           1           1
# ...

# %%
for k in [2]:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    df[f"Cluster_K{k}"] = kmeans.fit_predict(X)

# %%
plt.figure(figsize=(6,4))
plt.scatter(df["Study_Hours"], df["Exam_Score"],
                c=df[f"Cluster_K{k}"], cmap="viridis", s=80)
plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1],
                c="red", marker="X", s=200, label="Centroids")
plt.xlabel("Study Hours")
plt.ylabel("Exam Score")
plt.title(f"K-Means Clustering (K={k})")
plt.legend()
plt.show()

# Show dataset with cluster assignments
print(df)
# Out:
#     Study_Hours  Exam_Score  Cluster  Cluster_K2  Cluster_K4  Cluster_K3
# 0             1          35        2           1           2           2
# 1             2          40        2           1           2           2
# 2             2          42        2           1           2           2
# 3             3          50        2           1           0           2
# 4             3          48        2           1           0           2
# 5             4          55        0           1           0           0
# 6             5          60        0           1           0           0
# 7             6          65        0           0           3           0
# 8             6          70        0           0           3           0
# 9             7          75        1           0           3           1
# 10            8          80        1           0           1           1
# 11            8          82        1           0           1           1
# ...
